# %%
import  numpy as np 
import  pandas as pd

# %%
df=pd.read_csv("healthcare-dataset-stroke-data.csv")
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df['Residence_type'].unique()
# Out:
# array(['Urban', 'Rural'], dtype=object)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan,
                        strategy ='mean')
imputer = imputer.fit(df[['bmi']])
 
# Imputing the data    
df['bmi'] = imputer.transform(df[['bmi']])
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# ...

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

#for Residence_type column
df['Residence_type']=lb.fit_transform(df['Residence_type'])


#for  smoking_status  column
df['smoking_status']=lb.fit_transform(df['smoking_status'])


#for ever_married column
df['ever_married']=lb.fit_transform(df['ever_married'])

#for ever_married column
df['gender']=lb.fit_transform(df['gender'])


#for work_type column

df['work_type']=lb.fit_transform(df['work_type'])
df['work_type'].unique()


#for  hypertension  column  
df['hypertension']=lb.fit_transform(df['hypertension'])
df['hypertension'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Residence_type'].unique()
# Out:
# array([1, 0])

# %%
X=df[['gender','age','hypertension','ever_married','work_type','avg_glucose_level','bmi','smoking_status']]
Y=df[['stroke']]

# %%
from  sklearn.model_selection  import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3)
x_train
# Out:
#       gender    age  hypertension  ever_married  work_type  avg_glucose_level  \
# 3887       1  20.00             0             0          2              87.20
# 4124       0  25.00             0             1          2              78.50
# 2030       1   0.48             0             0          4              73.02
# 3434       1  14.00             0             0          3              72.28
# 4402       1  34.00             0             1          2              83.75
# ...      ...    ...           ...           ...        ...                ...
# 1943       1  34.00             0             0          2              69.09
# 1947       0  25.00             0             0          2              65.95
# 643        0  80.00             0             1          3              79.09
# 3355       1  23.00             0             0          2              67.76
# 2452       0  19.00             0             0          0             133.58
#
#             bmi  smoking_status
# ...

# %%
from sklearn.linear_model  import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# c:\Users\slrk4\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\slrk4\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#[[1,67.0,0,1,0,93.71,31.200000,1]]
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9497716894977168

# %%
import pickle

# %%
with  open('stroke_model','wb') as f:
    pickle.dump(model,f)

# %%
f= open('stroke_model','rb') 
mp=pickle.load(f)

# %%
 ans=mp.predict([[1,67.0,0,1,0,93.71,31.200000,1]])
print(ans[0])
# Out:
# 0
# c:\Users\slrk4\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
